# %%
import pandas as pd
import numpy as np

# %%
label = np.array([2,4,6,8])
ind = np.array(["a","b","c","d"])
ser = pd.Series(data = label, index = ind)

# %%
ser
# Out:
# a    2
# b    4
# c    6
# d    8
# dtype: int32

# %%
dic = {1:"mohamed",2 : "adel", 3 : "mahmoud"}

# %%
ser2 = pd.Series(dic)
ser2
# Out:
# 1    mohamed
# 2       adel
# 3    mahmoud
# dtype: object

# %%
ser2[1]
# Out:
# 'mohamed'

# %%
ser2[2]
# Out:
# 'adel'

# %%
data = pd.DataFrame(np.empty((3,3)),["a","b","c"],["qw","er","rt"])
data
# Out:
#     qw   er             rt
# a  0.0  0.0   0.000000e+00
# b  0.0  0.0  1.454529e-320
# c  0.0  0.0   0.000000e+00

# %%
df = pd.read_csv(r"train.csv")

# %%
df[["Sex","Survived"]]
# Out:
#         Sex  Survived
# 0      male         0
# 1    female         1
# 2    female         1
# 3    female         1
# 4      male         0
# ..      ...       ...
# 886    male         0
# 887  female         1
# 888  female         0
# 889    male         1
# 890    male         0
#
# [891 rows x 2 columns]

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# #### drop a column

# %%
df.drop(["Name"],axis = 1,inplace = True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch  \
# 0              1         0       3    male  22.0      1      0
# 1              2         1       1  female  38.0      1      0
# 2              3         1       3  female  26.0      0      0
# 3              4         1       1  female  35.0      1      0
# 4              5         0       3    male  35.0      0      0
# ..           ...       ...     ...     ...   ...    ...    ...
# 886          887         0       2    male  27.0      0      0
# 887          888         1       1  female  19.0      0      0
# 888          889         0       3  female   NaN      1      2
# 889          890         1       1    male  26.0      0      0
# 890          891         0       3    male  32.0      0      0
#
#                Ticket     Fare Cabin Embarked
# 0           A/5 21171   7.2500   NaN        S
# 1            PC 17599  71.2833   C85        C
# 2    STON/O2. 3101282   7.9250   NaN        S
# ...

# %% [markdown]
# #### loc and iloc

# %%
df.loc[:5,"Survived":"Ticket"]
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch            Ticket
# 0         0       3    male  22.0      1      0         A/5 21171
# 1         1       1  female  38.0      1      0          PC 17599
# 2         1       3  female  26.0      0      0  STON/O2. 3101282
# 3         1       1  female  35.0      1      0            113803
# 4         0       3    male  35.0      0      0            373450
# 5         0       3    male   NaN      0      0            330877

# %%
df.loc[:5,["Survived","Ticket"]]
# Out:
#    Survived            Ticket
# 0         0         A/5 21171
# 1         1          PC 17599
# 2         1  STON/O2. 3101282
# 3         1            113803
# 4         0            373450
# 5         0            330877

# %%
df.iloc[:3,4:6]
# Out:
#     Age  SibSp
# 0  22.0      1
# 1  38.0      1
# 2  26.0      0

# %% [markdown]
# ### Filteration

# %%
df["Age"] > 25
# Out:
# 0      False
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 886     True
# 887    False
# 888    False
# 889     True
# 890     True
# Name: Age, Length: 891, dtype: bool

# %%
df[(df["Age"] > 25) & (df["Age"] < 50)] # we filter the data by two conditions
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch  \
# 1              2         1       1  female  38.0      1      0
# 2              3         1       3  female  26.0      0      0
# 3              4         1       1  female  35.0      1      0
# 4              5         0       3    male  35.0      0      0
# 8              9         1       3  female  27.0      0      2
# ..           ...       ...     ...     ...   ...    ...    ...
# 883          884         0       2    male  28.0      0      0
# 885          886         0       3  female  39.0      0      5
# 886          887         0       2    male  27.0      0      0
# 889          890         1       1    male  26.0      0      0
# 890          891         0       3    male  32.0      0      0
#
#                Ticket     Fare Cabin Embarked
# 1            PC 17599  71.2833   C85        C
# 2    STON/O2. 3101282   7.9250   NaN        S
# 3              113803  53.1000  C123        S
# ...

# %%
df["Sex"].unique() # return the categories in the column
# Out:
# array(['male', 'female'], dtype=object)

# %%
df["Sex"].nunique() # return the number of categories
# Out:
# 2

# %%
df["Sex"].value_counts() # return how many Samples in every category
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64
